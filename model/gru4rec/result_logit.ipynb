# %%
import numpy as np
import matplotlib.pyplot as plt

logits = np.load("D:\movierec\model\gru4rec\submission\submission_logits.npy")

# 여러 유저면 flatten
if logits.ndim == 2:
    values = logits.flatten()
else:
    values = logits

plt.hist(values, bins=100)
plt.title("Logit Distribution")
plt.xlabel("logit value")
plt.ylabel("count")
plt.show()
